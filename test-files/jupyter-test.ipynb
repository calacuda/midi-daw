# %%
from midi_daw import *

# %%
get_devs()
# Out:
# ['Midi Through:0',
#  'SP-404MKII:0',
#  'microKORG2:0',
#  'monologue:0',
#  'monologue:1',
#  'TD-3-MO:0']

# %%
tempo()
# Out:
# 99.0

# %%
tempo(99)
# Out:
# 99.0

# %%
def start_event():
    wait_for("1")

# %%
def sp(pad_n: int) -> int:
    if pad_n <= 4:
        return 47 + pad_n
    elif pad_n <= 8:
        return 43 + (pad_n - 4)
    elif pad_n <= 12:
        return 39 + (pad_n - 8)
    elif pad_n <= 16:
        return 35 + (pad_n - 12)

# %%
def do_drums(pad):
    note([sp(4), sp(1)], sn(), vel=100)
    note(sp(1), sn(1), vel=100)
    note(
        [sp(7), sp(1)],
        sn(),
        vel=127,
    )
    note(sp(1), sn(1), vel=100)
    note([sp(4), sp(1)], sn(), vel=100)
    note(sp(11), sn(1), vel=100)
    note([sp(7)], sn(), vel=100)
    note(sp(pad), sn(1), vel=100)

# %%
@play_on("sp404", channel=Ch1, block=False, loop=-1, setup=start_event)
def drums():
    # 36 - 52
    do_drums(1)
    do_drums(9)

# %%
drums()
# Out:
# 'drums:sp404:1'

# %%
drums.stop()
# Out:
# INFO:midi_daw.main:stopped function drums:sp404:1

# %%
def start_on(beat):
    def _start_on():
        return wait_for(beat)

    return _start_on

# %%
# ```python

times_looped = 0

@play_on("sp404", channel=Ch1, block=False, loop=-1, setup=start_event)
def four_on_floor(vel):
    global times_looped
    clap_beat = [sp(2), sp(4), sp(9)] if times_looped > 4 else [sp(2), sp(4)] 
    
    for n in (
        [sp(2), sp(4)],
        clap_beat,
        [sp(2), sp(4)],
        clap_beat,
        
        # [sp(2), sp(4), sp(9)],
    ):
        note(n, en(), vel)
        rest(sn())
        
        if times_looped > 8:
            note(sp(10), en(), vel)
        else:
            rest(en())
        
        rest(sn())

    times_looped += 1
    
# ```

four_on_floor.stop()
four_on_floor(100)
# Out:
# INFO:midi_daw.main:stopped function four_on_floor:sp404:1
# 'four_on_floor:sp404:1'
# Process Process-18:
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 578, in loop_f
#     self.func(*args, *kwargs)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_291706/2645392382.py", line 19, in four_on_floor
#     rest(sn())
#     ~~~~^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 259, in rest
#     post(duration.json(), "rest")
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 145, in post
#     res = requests.post(
#         f"http+unix://{socket}/{path}",
#         data=data,
#         headers=headers,
#     )
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests_unixsocket/__init__.py", line 60, in post
#     return request('post', url, data=data, json=json, **kwargs)
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests_unixsocket/__init__.py", line 46, in request
#     return session.request(method=method, url=url, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests/adapters.py", line 644, in send
#     resp = conn.urlopen(
#         method=request.method,
#     ...<9 lines>...
#         chunked=chunked,
#     )
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#         conn,
#     ...<10 lines>...
#         **response_kw,
#     )
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/urllib3/connection.py", line 565, in getresponse
#     httplib_response = super().getresponse()
#   File "/usr/lib/python3.13/http/client.py", line 1430, in getresponse
#     response.begin()
#     ~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/http/client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ~~~~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/http/client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/socket.py", line 719, in readinto
#     return self._sock.recv_into(b)
#            ~~~~~~~~~~~~~~~~~~~~^^^
# KeyboardInterrupt

# %%
td_loop = 0

@play_on("td3", channel=Ch1, block=False, loop=-1, setup=start_event)
def td(vel):
    global td_loop
    
    vel = 100

    # 
    panic()

    roll = 2
    
    # for _ in range(2): 
    if td_loop == 0:
        roll += 1
    
    note("f4", en(), vel)
    note("a3", en(), vel)
    note("f4", en(), vel)
    note("d4", en(), vel)
    # note("e4", en(), vel)
    
    for _ in range(roll):
        note("f3", sn(), vel)
        rest(sn())

    note("f2", en(), vel)
    rest(sn())
    note("d3", en(), vel)
    rest(sn())
    note("d4", en(), vel)
    rest(sn())
    note("f3", en(), vel)
    # rest(sn())
    # note("d3", en(), vel)
    # rest(sn())
    # rest(sn())
    
    
    td_loop += 1
    
# ```

td.stop()
panic(td.new_midi_out)
td(100)
# Out:
# INFO:midi_daw.main:stopped function td:td3:1
# 'td:td3:1'
# Process Process-20:
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 578, in loop_f
#     self.func(*args, *kwargs)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_291706/3364720163.py", line 21, in td
#     note("d4", en(), vel)
#     ~~~~^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 543, in note
#     self.send_note_to(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 229, in note
#     send_midi_cmd(midi_cmd)
#     ~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 223, in send_midi_cmd
#     midi_out(cmd, block=block)
#     ~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 195, in _midi_out
#     return _do_midi_out(midi_target, midi_cmd)
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 171, in _do_midi_out
#     post(MidiReqBody(midi_target.name, midi_target.ch, midi_cmd).json(), "midi")
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 145, in post
#     res = requests.post(
#         f"http+unix://{socket}/{path}",
#         data=data,
#         headers=headers,
#     )
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests_unixsocket/__init__.py", line 60, in post
#     return request('post', url, data=data, json=json, **kwargs)
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests_unixsocket/__init__.py", line 46, in request
#     return session.request(method=method, url=url, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests/adapters.py", line 644, in send
#     resp = conn.urlopen(
#         method=request.method,
#     ...<9 lines>...
#         chunked=chunked,
#     )
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#         conn,
#     ...<10 lines>...
#         **response_kw,
#     )
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/urllib3/connection.py", line 565, in getresponse
#     httplib_response = super().getresponse()
#   File "/usr/lib/python3.13/http/client.py", line 1430, in getresponse
#     response.begin()
#     ~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/http/client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ~~~~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/http/client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/socket.py", line 719, in readinto
#     return self._sock.recv_into(b)
#            ~~~~~~~~~~~~~~~~~~~~^^^
# KeyboardInterrupt

# %%
td.stop()
panic(td.new_midi_out)
# Out:
# INFO:midi_daw.main:stopped function td:td3:1

# %%
def f_on_f_stop():
    _four_on_floor_beat.stop()
    _four_on_floor_clap.stop()
    _four_on_floor_hh.stop()


@play_on("sp404", channel=Ch1, block=False, loop=-1, setup=start_event)
def _four_on_floor_beat(step, vel):
    note([sp(2), sp(4)], step(), vel)
    rest(step(3))


@play_on("sp404", channel=Ch1, block=False, loop=-1)
def _four_on_floor_hh(step, vel):
    rest(step(2))
    note(sp(1), step(), vel)
    rest(step())


@play_on("sp404", channel=Ch1, block=False, loop=-1)
def _four_on_floor_clap(step, vel):
    rest(step(4))
    note(sp(9), step(), vel)
    rest(step(3))


# @play_on("sp404", channel=Ch1, block=False, loop=1, setup=start_event)
def four_on_floor():
    vel = 100
    step = en

    # wait_for("1")
    log.info("start main beat")
    _four_on_floor_beat(step, vel) 
    start_event()
    start_event()
    log.info("start clap")
    _four_on_floor_clap(step, vel)
    # wait_for("1")
    log.info("start hh")
    _four_on_floor_hh(step, vel)


f_on_f_stop()
four_on_floor()
# Out:
# INFO:midi_daw.main:stopped function _four_on_floor_beat:sp404:1
# INFO:midi_daw.main:stopped function _four_on_floor_clap:sp404:1
# INFO:midi_daw.main:stopped function _four_on_floor_hh:sp404:1
# INFO:midi_daw.main:start main beat
# Process Process-16:
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 45
#      41     _four_on_floor_hh(step, vel)
#      44 f_on_f_stop()
# ---> 45 four_on_floor()
#
# Cell In[17], line 36, in four_on_floor()
#      34 _four_on_floor_beat(step, vel)
#      35 start_event()
# ---> 36 start_event()
#      37 log.info("start clap")
#      38 _four_on_floor_clap(step, vel)
#
# Cell In[6], line 2, in start_event()
#       1 def start_event():
# ----> 2     wait_for("1")
#
# File ~/Code/rust/midi-daw/python-lib/midi_daw/main.py:322, in wait_for(event)
#     319 recv = recv.replace('"', "")
#     321 while not check(recv):
# --> 322     recv = ws.recv()
#     323     recv = recv.replace('"', "")
#     325 log.debug("event recved")
#
# File ~/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/websockets/sync/connection.py:317, in Connection.recv(self, timeout, decode)
#     269 """
#     270 Receive the next message.
#     271
#    (...)    314
#     315 """
#     316 try:
# --> 317     return self.recv_messages.get(timeout, decode)
#     318 except EOFError:
#     319     pass
#
# File ~/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/websockets/sync/messages.py:169, in Assembler.get(self, timeout, decode)
#     166 deadline = Deadline(timeout)
#     168 # First frame
# --> 169 frame = self.get_next_frame(deadline.timeout(raise_if_elapsed=False))
#     170 with self.mutex:
#     171     self.maybe_resume()
#
# File ~/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/websockets/sync/messages.py:87, in Assembler.get_next_frame(self, timeout)
#      85         frame = self.frames.get(block=False)
#      86     else:
# ---> 87         frame = self.frames.get(block=True, timeout=timeout)
#      88 except queue.Empty:
#      89     raise TimeoutError(f"timed out in {timeout:.1f}s") from None
#
# KeyboardInterrupt:
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 578, in loop_f
#     self.func(*args, *kwargs)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_291706/556459541.py", line 10, in _four_on_floor_beat
#     rest(step(3))
#     ~~~~^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 259, in rest
#     post(duration.json(), "rest")
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/python-lib/midi_daw/main.py", line 145, in post
#     res = requests.post(
#         f"http+unix://{socket}/{path}",
#         data=data,
#         headers=headers,
#     )
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests_unixsocket/__init__.py", line 60, in post
#     return request('post', url, data=data, json=json, **kwargs)
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests_unixsocket/__init__.py", line 46, in request
#     return session.request(method=method, url=url, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/requests/adapters.py", line 644, in send
#     resp = conn.urlopen(
#         method=request.method,
#     ...<9 lines>...
#         chunked=chunked,
#     )
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#         conn,
#     ...<10 lines>...
#         **response_kw,
#     )
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#   File "/home/yogurt/Code/rust/midi-daw/.venv/lib/python3.13/site-packages/urllib3/connection.py", line 565, in getresponse
#     httplib_response = super().getresponse()
#   File "/usr/lib/python3.13/http/client.py", line 1430, in getresponse
#     response.begin()
#     ~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/http/client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ~~~~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/http/client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/socket.py", line 719, in readinto
#     return self._sock.recv_into(b)
#            ~~~~~~~~~~~~~~~~~~~~^^^
# KeyboardInterrupt

# %%
four_on_floor.stop()
f_on_f_stop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 four_on_floor.stop()
#       2 f_on_f_stop()
#
# AttributeError: 'function' object has no attribute 'stop'

# %%
tempo()
# Out:
# 64.0

# %%
tempo(99)
# Out:
# 99.0
